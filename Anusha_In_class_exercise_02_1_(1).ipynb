# %% [markdown]
# ## The third In-class-exercise (02/08/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

List Of Bollywood Films from 2000 to 2007
------------------------------------------
Bollywood is the biggest film industry in India. This film industry runs its production from Mumbai. 
I am very intersted in bollywood films so I experimented in scraping list of bollywood films using URLs.
As bollywood film industry includes movies those are directed in Hindi, Urdu, Punjabi and more it felt it interesting to scrape details of film like 
genre of film so that we can analyze more from genres like interests of directers in making films.

To do this I followed the following steps:
step1:
I installed beautiful soup which is very intersting web scraping library in python

step 2:
I imported basic python libraries like pandas and numpy

step3: 
I mentioned column names that I want for my data frame 

step4:
I Used requests to access URL

step5:
I printed soup

step6:
Iterating rows using classes and placed in table

Step 7:
copied data in to dataframe

step 8:
I printed dataset




'''
# Out:
# '\nPlease write you answer here:\n\nList Of Bollywood Films from 2000 to 2007\n------------------------------------------\nBollywood is the biggest film industry in India. This film industry runs its production from Mumbai. \nI am very intersted in bollywood films so I experimented in scraping list of bollywood films using URLs.\nAs bollywood film industry includes movies those are directed in Hindi, Urdu, Punjabi and more it felt it interesting to scrape details of film like \ngenre of film so that we can analyze more from genres like interests of directers in making films.\n\nTo do this I followed the following steps:\nstep1:\nI installed beautiful soup which is very intersting web scraping library in python\n\nstep 2:\nI imported basic python libraries like pandas and numpy\n\nstep3: \nI mentioned column names that I want for my data frame \n\nstep4:\nI Used requests to access URL\n\nstep5:\nI printed soup\n\nstep6:\nIterating rows using classes and placed in table\n\nStep 7:\ncop
# ...

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):
#to collect samples of data I used webscrapping using beautiful soup
#installing beautiful soup
from bs4 import BeautifulSoup

# %%
#to aceess URL
import requests

# %%
#Importing libraries to import data
import pandas as pd
import numpy as np

# %%
#defining a data frame and mentioning columns
columns=['Movie_ID','Title','Year','Genre']
df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [Movie_ID, Title, Year, Genre]
# Index: []

# %%
#As we are using data related to multiple years from 2000 to 2007 we use multiple URLS
URL = {2000:'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2000',
       2001:'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2001',
       2002:'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2002',    
       2003:'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2003',
       2004:'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2004',
       2005:'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2005',
       2006:'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2006',
       2007:'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2007'
      }

# %%
id = 0
for key, url in URL.items():
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.findAll('table', {'class':'wikitable'})[1].tbody
    rows = table.find_all('tr')
    for i in range(1, len(rows)):
        tds = rows[i].find_all('td')
        values = [id,tds[0].text, key, tds[3].text]
        id+=1
        df = df.append(pd.Series(values, index=columns), ignore_index=True)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Bollywood films of 2007 - Wikipedia</title>
# ...

# %%
df.shape
# Out:
# (782, 4)

# %%
#collecting 1000 samples of data
df.head(1000)
# Out:
#     Movie_ID             Title  Year             Genre
# 0          0          Aaghaaz   2000          Thriller
# 1          1      Aaj Ka Ravan  2000             Drama
# 2          2           Anjaane  2000           Romance
# 3          3       Anokha Moti  2000            Family
# 4          4      Apradhi Kaun  2000          Thriller
# ..       ...               ...   ...               ...
# 777      777         The Train  2007  Drama Thriller\n
# 778      778  Victoria No. 203  2007          Comedy\n
# 779      779           Welcome  2007          Comedy\n
# 780      780             Yatra  2007           Drama\n
# 781      781          Zamaanat  2007           Drama\n
#
# [782 rows x 4 columns]

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):
url ='https://dl.acm.org/'
response = requests.get(url)
soup1 = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup1)
# Out:
# <!DOCTYPE html>
#
# <html class="pb-page" data-request-id="f23d615f-6fa4-45a9-b8b2-9a3153c85726" lang="en"><head data-pb-dropzone="head"><meta content=";website:website:dl-site;wgroup:string:ACM Publication Websites;page:string:Home Page" name="pbContext"/>
# <title>ACM Digital Library</title>
# <meta charset="utf-8"/>
# <meta content="noarchive" name="robots">
# <meta content="ACM Digital Library Home page" name="description"/>
# <meta content="ACM Digital Library" property="og:title"/>
# <meta content="Website" property="og:type"/>
# <meta content="ACM Digital Library" property="og:site_name"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# ...

# %%
title = soup.findAll("h2", class_="subject-browse__meta")

# %%
title
# Out:
# []

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
page_url = 'http://dev.to'

response = requests.get(page_url)

soup3 = BeautifulSoup(response.content, "html.parser")

# %%
soup3
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>DEV Community 👩‍💻👨‍💻</title>
# <meta content="2022-02-12 07:55:10 UTC" name="last-updated"/>
# <meta content="false" name="user-signed-in"/>
# <meta content="1644652510" name="head-cached-at"/>
# <!-- Experimental web monetization payment pointer for micropayments -->
# <!-- It lets readers make micropayments to websites they visit. -->
# <!-- This is step 1: Get live in production to test for platform-wide payment pointer. -->
# <!-- Step 2: Allow authors to set their payment pointer so they can directly monetize their content based on visitors. -->
# <!-- Step 3: Enable further functionality based on what we learn from this experimentation and how the ecosystem evolves. -->
# <meta content="$ilp.uphold.com/24HhrUGG7ekn" name="monetization"/>
# <meta content="production" name="environment"/>
# ...

# %%
def scrape():
    page = requests.get("http://dev.to")
    soup = BeautifulSoup(page.content, "html.parser")
    home = soup.find(class_="articles-list crayons-layout__content")
    posts = home.find_all(class_="crayons-story__indention")
    top_post = posts[0].find("h2", class_="crayons-story__title").text.strip()
    tweet(top_post)

# %%
pip install tweepy

# %%
import tweepy

# %%
def tweet(top_post):
    consumer_key = "#"
    consumer_secret = "#"
    access_token = "#"
    access_token_secret = "#"
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    api.update_status(top_post)

scrape()
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-54-83a3ea700b16> in <module>()
#      10     api.update_status(top_post)
#      11
# ---> 12 scrape()
#
# <ipython-input-51-fadbcca1a3e9> in scrape()
#       5     posts = home.find_all(class_="crayons-story__indention")
#       6     top_post = posts[0].find("h2", class_="crayons-story__title").text.strip()
# ----> 7     tweet(top_post)
#       8
#       9
#
# <ipython-input-54-83a3ea700b16> in tweet(top_post)
#       8     auth.set_access_token(access_token, access_token_secret)
#       9     api = tweepy.API(auth)
# ---> 10     api.update_status(top_post)
#      11
#      12 scrape()
#
# /usr/local/lib/python3.7/dist-packages/tweepy/api.py in update_status(self, *args, **kwargs)
#     216                            'card_uri'],
#     217             require_auth=True
# --> 218         )(*args, **kwargs)
# ...
